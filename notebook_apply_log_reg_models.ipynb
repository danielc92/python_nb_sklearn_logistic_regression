# %% [markdown]
# # Applying Logistic Regression Model Workflow

# %% [markdown]
# ## Import relevant modules

# %%
import pandas
import math

# %% [markdown]
# ## Store intercept, column names, coefficients and output column name variables

# %%
intercept =.92428029
column_names =['height_B', 'reach_A', 'won_B', 'lost_A', 'lost_B', 'drawn_A',
       'drawn_B', 'kos_B', 'age_diff', 'kd_diff_B', 'stance_A_southpaw',
       'stance_B_southpaw']
coefficients =[-0.026907131594570408, 0.02965530670846954, 0.07293576251518107, -0.09885390749492504, 0.10424850798319237, -0.028024100297096764, -0.03992409120896212, -0.0639861490523247, -0.022415465347209652, -0.031312745466804244, 0.015331346599411426, 0.015331346599411426]
output_y = 'result'

# %% [markdown]
# ## Read in test data

# %%
subset_path = "/Users/danielcorcoran/PycharmProjects/daniels_mac_proj/jupyter_notebooks/logistic_regression/boxing_last_x_records.csv"
data = pandas.read_csv(subset_path)

# %% [markdown]
# ## Calculate the predicted outcome, using the inputs from the model

# %%
partial_total = intercept
ypred = "model_output_prediction"
match_flag_name = "model_prediction_true_or_false"

for index in range(len(column_names)):
    partial_total = partial_total + data[column_names[index]] * coefficients[index]

full_formula = 1 / (1 + math.exp(1)**-(partial_total))

data = pandas.concat(
    [data,
     full_formula.ge(.5).replace([True, False], [1, 0]).rename(ypred)],
    axis=1)

old_result_list = data[output_y].tolist()
new_result_list = data[ypred].tolist()

total_possible = len(old_result_list)

# %% [markdown]
# ## Create column, if predicted value matches the actual value

# %%
match_list = []

for n in range(len(old_result_list)):
    if old_result_list[n] == new_result_list[n]:
        match_list.append(1)
    else:
        match_list.append(0)

data = pandas.concat(
    [data, pandas.Series(match_list).rename(match_flag_name)], axis=1)

# %% [markdown]
# ## Checking subset of final data

# %%
data.head(10)
# Out:
#    Unnamed: 0  age_A  age_B  height_A  height_B  reach_A  reach_B  weight_A  \
# 0        2228   30.0   43.0     191.0     192.0    198.0    198.0     235.0
# 1        2229   40.0   32.0     192.0     188.0    198.0    196.0     231.0
# 2        2230   39.0   30.0     192.0     191.0    198.0    206.0     237.0
# 3        2231   38.0   35.0     192.0     185.0    198.0    196.0     230.0
# 4        2232   38.0   31.0     192.0     193.0    198.0    203.0     228.0
# 5        2233   33.0   31.0     192.0     193.0    198.0    216.0     236.0
# 6        2234   29.0   25.0     192.0     194.0    198.0    211.0     217.0
# 7        2235   28.0   27.0     192.0     190.0    198.0    201.0     227.0
# 8        2236   26.0   26.0     192.0     191.0    198.0    196.0     217.0
# 9        2237   26.0   23.0     160.0     173.0    160.0    173.0     112.0
#
#    weight_B  won_A               ...                age_diff  height_diff  \
# ...

# %%
data[[output_y, ypred, match_flag_name]]
# Out:
#      result  model_output_prediction  model_prediction_true_or_false
# 0         1                        1                               1
# 1         0                        1                               0
# 2         0                        1                               0
# 3         0                        1                               0
# 4         1                        1                               1
# 5         1                        1                               1
# 6         1                        1                               1
# 7         1                        1                               1
# 8         0                        1                               0
# 9         1                        1                               1
# 10        0                        1                               0
# 11        1                        1                               1
# 12        1                        1                               1
# ...

# %% [markdown]
# ## Calculate the accuracy of the model against the test subset

# %%
accuracy = "{:.2%}".format(data[match_flag_name].sum()/data.shape[0])
print("Accuracy of model against test subset: ",accuracy)
# Out:
# Accuracy of model against test subset:  88.00%

# %% [markdown]
# ## Export data (optional)

# %%
data.to_csv("boxing_data_tested_against_model.csv")
